# %% [markdown]
# # 0.6 New note in Single page app diagram
#
# ![new_note_in_sp](./new_note_in_single_page.png)
#
# sequenceDiagram
#     participant browser
#     participant server
#
#     Note over browser: The user enters and submits information, triggering the form submission process.
#     Note over browser: The program immediately calls the method e.preventDefault() to prevent the default handling of the form submission.
#     Note over browser: Event handler re-renders.
#
#     browser->>server: HTTP POST https://studies.cs.helsinki.fi/exampleapp/new_note_spa <br/> Payload: { "content": "new note", "date": "2026-09-18" }
#     activate server
#     Note over server: The server read the data and adds it to the list of notes.
#     server-->>browser: HTTP 201 Created <br/> Response: {"message":"note created"}
#     deactivate server
