# %% [markdown]
# # 0.5 single page app diagram and its code
#
# ![single_page](./single_page.png)
#
# sequenceDiagram
#     participant browser
#     participant server
#
#     browser->>server: HTTP GET https://studies.cs.helsinki.fi/exampleapp/spa
#     activate server
#     server-->>browser: HTML-code (spa.html)
#     deactivate server
#
#     browser->>server: HTTP GET https://studies.cs.helsinki.fi/exampleapp/main.css
#     activate server
#     server-->>browser: main.css
#     deactivate server
#
#     browser->>server: HTTP GET https://studies.cs.helsinki.fi/exampleapp/spa.js
#     activate server
#     server-->>browser: spa.js
#     deactivate server
#
#     Note over browser: browser starts executing the js code
#
#     browser->>server: HTTP GET https://studies.cs.helsinki.fi/exampleapp/data.json
#     activate server
#     server-->>browser: data.json
#     deactivate server
#
#     Note over browser: browser renders the page
#
#     browser->>server: HTTP GET https://studies.cs.helsinki.fi/favicon.ico
#     activate server
#     server-->>browser: HTTP 404 Not Found
#     deactivate server
